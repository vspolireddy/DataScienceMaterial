# %% [markdown]
# # Problem 1(a).  College data.
#
# The data set usnews.csv contains data from the 1995 US News and World Report on colleges and universities in the US.
#
# (Dataset:  “US News College data,” submitted by Robin Lock, St. Lawrence University.   Dataset obtained from the Journal of Statistics Education (http://www.amstat.org/publications/jse). Accessed 23 June 2015. Used by permission of author.)
#
# Metadata:  http://www.amstat.org/publications/jse/datasets/usnews.txt
#
#
# The data set contains asterisks which indicate missing data.  Use pandas to create a data frame which replaces the asterisks by the ```NaN``` symbol.

# %%
import pandas as pd
import numpy as np

file_usNews = pd.read_csv("usnews.csv")
file_usNews[0:5]


#we write a function to replace * with NaN
def rm_stars(isStar):
    if isStar == "*":
        return np.nan
    else:
        return isStar

# %%
file_usNews = file_usNews.applymap(rm_stars)
file_usNews[0:5]
# Out:
#    ID Number                       College Name  State   Public/private  \
# 0       1061          Alaska Pacific University     AK                2
# 1       1063  University of Alaska at Fairbanks     AK                1
# 2       1065     University of Alaska Southeast     AK                1
# 3      11462  University of Alaska at Anchorage     AK                1
# 4       1002        Alabama Agri. & Mech. Univ.     AL                1
#
#    Avg Math SAT  Avg Verbal SAT  Avg combined SAT  Avg ACT  \
# 0           490             482               972       20
# 1           499             462               961       22
# 2           NaN             NaN               NaN      NaN
# 3           459             422               881       20
# 4           NaN             NaN               NaN       17
#
#    First quartile - Math SAT  Third quartile - Math SAT       ...         \
# 0                        440                        530       ...
# 1                        NaN                        NaN       ...
# 2                        NaN                        NaN       ...
# 3                        NaN                        NaN       ...
# 4                        NaN                        NaN       ...
#
#    Board costs  Additional fees  Estimated book costs  \
# 0         2500              130                   800
# 1         1790              155                   650
# 2         2250               34                   500
# 3         2520              114                   580
# 4         1442              155                   500
#
#    Estimated personal spending  Pct of faculty with PhDs  \
# 0                         1500                        76
# 1                         2304                        67
# 2                         1162                        39
# 3                         1260                        48
# 4                          850                        53
#
#    Pct of faculty with terminal degree  Student/faculty ratio  \
# 0                                   72                   11.9
# 1                                  NaN                   10.0
# 2                                   51                    9.5
# 3                                  NaN                   13.7
# 4                                   53                   14.3
#
#    Pct alumni who donate  Instructional expenditure per student  \
# 0                      2                                  10922
# 1                      8                                  11935
# 2                    NaN                                   9584
# 3                      6                                   8046
# 4                    NaN                                   7043
#
#    Graduation rate
# 0               15
# 1              NaN
# 2               39
# 3              NaN
# 4               40
#
# [5 rows x 35 columns]

# %% [markdown]
# #Problem 1(b).  Categorizing universities.
#
# Create a new column in your data frame which describes whether a university is public or private, using the words "Public" and "Private" instead of numbers.  (It may be helpful to consult the metadata file.)

# %%
# public is 1
# private is 2
file_usNews['Private or Public'] = file_usNews[' Public/private'].map(lambda s: 'Public' if s == 1 else 'Private')


file_usNews[0:10]

file_usNews = file_usNews.applymap(rm_stars)

# %% [markdown]
# #Problem 1(c).
#
# The interquartile range is the 3rd quartile minus the 1st quartile.  Create columns recording the interquartile range for math and verbal SAT scores.

# %%
# finds the interquartile Math SAT = 3rd quartile - 1st quartile
file_usNews['InterQ_Verbal_SAT'] = file_usNews[' Third quartile - Verbal SAT'].astype('float') - file_usNews[' First quartile - Verbal SAT'].astype('float')

# %%
# finds the interquartile verbal SAT = 3rd quartile - 1st quartile
file_usNews['InterQ_Math_SAT'] = file_usNews[' Third quartile - Math SAT'].astype('float') - file_usNews[' First quartile - Math SAT'].astype('float')

# %%
file_usNews[0:5]
# Out:
#    ID Number                       College Name  State   Public/private  \
# 0       1061          Alaska Pacific University     AK                2
# 1       1063  University of Alaska at Fairbanks     AK                1
# 2       1065     University of Alaska Southeast     AK                1
# 3      11462  University of Alaska at Anchorage     AK                1
# 4       1002        Alabama Agri. & Mech. Univ.     AL                1
#
#    Avg Math SAT  Avg Verbal SAT  Avg combined SAT  Avg ACT  \
# 0           490             482               972       20
# 1           499             462               961       22
# 2           NaN             NaN               NaN      NaN
# 3           459             422               881       20
# 4           NaN             NaN               NaN       17
#
#    First quartile - Math SAT  Third quartile - Math SAT        ...         \
# 0                        440                        530        ...
# 1                        NaN                        NaN        ...
# 2                        NaN                        NaN        ...
# 3                        NaN                        NaN        ...
# 4                        NaN                        NaN        ...
#
#    Estimated personal spending  Pct of faculty with PhDs  \
# 0                         1500                        76
# 1                         2304                        67
# 2                         1162                        39
# 3                         1260                        48
# 4                          850                        53
#
#    Pct of faculty with terminal degree  Student/faculty ratio  \
# 0                                   72                   11.9
# 1                                  NaN                   10.0
# 2                                   51                    9.5
# 3                                  NaN                   13.7
# 4                                   53                   14.3
#
#    Pct alumni who donate  Instructional expenditure per student  \
# 0                      2                                  10922
# 1                      8                                  11935
# 2                    NaN                                   9584
# 3                      6                                   8046
# 4                    NaN                                   7043
#
#    Graduation rate Private or Public InterQ_Math_SAT InterQ_Verbal_SAT
# 0               15           Private              90               120
# 1              NaN            Public             NaN               NaN
# 2               39            Public             NaN               NaN
# 3              NaN            Public             NaN               NaN
# 4               40            Public             NaN               NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# # Problem 1(d).  Saving for R.
#
# Save your data frame as a .csv file for further analysis in R.  You should replace the ```NaN``` symbol with an empty string before saving.  Your output should not include a column of row numbers.

# %%
file_usNews.fillna("", inplace=True)
file_usNews
# Out:
#       ID Number                           College Name  State  \
# 0          1061              Alaska Pacific University     AK
# 1          1063      University of Alaska at Fairbanks     AK
# 2          1065         University of Alaska Southeast     AK
# 3         11462      University of Alaska at Anchorage     AK
# 4          1002            Alabama Agri. & Mech. Univ.     AL
# 5          1003                    Faulkner University     AL
# 6          1004               University of Montevallo     AL
# 7          1005               Alabama State University     AL
# 8          1009          Auburn University-Main Campus     AL
# 9          1012            Birmingham-Southern College     AL
# 10         1016            University of North Alabama     AL
# 11         1019                     Huntingdon College     AL
# 12         1020          Jacksonville State University     AL
# 13         1023                         Judson College     AL
# 14         1024                  Livingston University     AL
# 15         1028                          Miles College     AL
# 16         1029                   University of Mobile     AL
# 17         1033                        Oakwood College     AL
# 18         1036                     Samford University     AL
# 19         1041                    Spring Hill College     AL
# 20         1044                       Stillman College     AL
# 21         1046                      Talladega College     AL
# 22         1047          Troy State University at Troy     AL
# 23         1050                    Tuskegee University     AL
# 24         1051    University of Alabama at Tuscaloosa     AL
# 25         1052    University of Alabama at Birmingham     AL
# 26         1055    University of Alabama at Huntsville     AL
# 27         1057            University of South Alabama     AL
# 28         8310        Auburn University at Montgomery     AL
# 29         1085   University of Arkansas at Monticello     AR
# ...         ...                                    ...    ...
# 1272       3911                        Viterbo College     WI
# 1273       3915          University of Wisconsin-Stout     WI
# 1274       3917       Univ. of Wisconsin at Eau Claire     WI
# 1275       3919       Univ.  of Wisconsin at La Crosse     WI
# 1276       3921      Univ. of Wisconsin at Platteville     WI
# 1277       3923      Univ. of Wisconsin at River Falls     WI
# 1278       3924    Univ. of Wisconsin at Stevens Point     WI
# 1279       3925       University of Wisconsin-Superior     WI
# 1280       3926     University of Wisconsin-Whitewater     WI
# 1281       5015    University of Wisconsin at Parkside     WI
# 1282       9630          Univ. of Wisconsin at OshKosh     WI
# 1283      21366             Wisconsin Lutheran College     WI
# 1284       3806              Alderson-Broaddus College     WV
# 1285       3808                        Bethany College     WV
# 1286       3809                Bluefield State College     WV
# 1287       3810                        Concord College     WV
# 1288       3811                 Davis & Elkins College     WV
# 1289       3812                 Fairmont State College     WV
# 1290       3813                Glenville State College     WV
# 1291       3815                    Marshall University     WV
# 1292       3818               University of Charleston     WV
# 1293       3820                Salem-Teikyo University     WV
# 1294       3822                       Shepherd College     WV
# 1295       3823             West Liberty State College     WV
# 1296       3825  West Virginia Institute of Technology     WV
# 1297       3826            West Virginia State College     WV
# 1298       3827               West Virginia University     WV
# 1299       3830         West Virginia Wesleyan College     WV
# 1300       3831                Wheeling Jesuit College     WV
# 1301       3932                  University of Wyoming     WY
#
#        Public/private  Avg Math SAT  Avg Verbal SAT  Avg combined SAT  \
# 0                   2           490             482               972
# 1                   1           499             462               961
# 2                   1
# 3                   1           459             422               881
# 4                   1
# 5                   2
# 6                   1
# 7                   1
# 8                   1           575             501              1076
# 9                   2           575             525              1100
# 10                  1
# 11                  2           513             446               959
# 12                  1
# 13                  2
# 14                  1
# 15                  2
# 16                  2
# 17                  2           382             378               760
# 18                  2
# 19                  2           525             480               990
# 20                  2
# 21                  2
# 22                  1           510             470               980
# 23                  2
# 24                  1
# 25                  1
# 26                  1           542             468              1010
# 27                  1
# 28                  1
# 29                  1
# ...               ...           ...             ...               ...
# 1272                2
# 1273                1
# 1274                1           525             460               985
# 1275                1
# 1276                1
# 1277                1
# 1278                1
# 1279                1
# 1280                1
# 1281                1
# 1282                1
# 1283                2
# 1284                2           443             394               837
# 1285                2           479             448               927
# 1286                1           420             370               780
# 1287                2
# 1288                2           437             399               836
# 1289                1
# 1290                1
# 1291                2           465             450               915
# 1292                2           505             443               948
# 1293                2
# 1294                2           481             422               903
# 1295                1
# 1296                1
# 1297                1
# 1298                1           507             439               946
# 1299                2           489             439               928
# 1300                2           479             433               912
# 1301                1
#
#       Avg ACT  First quartile - Math SAT  Third quartile - Math SAT  \
# 0          20                        440                        530
# 1          22
# 2
# 3          20
# 4          17
# 5          20
# 6          21
# 7
# 8          24                        520                        638
# 9          26                        470                        680
# 10
# 11         23                        480                        570
# 12         20
# 13         22
# 14         19
# 15
# 16         22
# 17         17
# 18                                   485                        585
# 19         24                        480                        550
# 20
# 21
# 22         20                        350                        480
# 23
# 24         23
# 25         21
# 26         24                        470                        610
# 27         23
# 28         21
# 29
# ...       ...                        ...                        ...
# 1272       22
# 1273       21
# 1274       23                        460                        585
# 1275
# 1276       22
# 1277
# 1278       22
# 1279       21
# 1280       21
# 1281       20
# 1282       22
# 1283       23
# 1284       20                        400                        510
# 1285       23
# 1286       19
# 1287       20
# 1288       19                        360                        500
# 1289       19
# 1290       19
# 1291       23
# 1292       21                        430                        550
# 1293       22                        370                        580
# 1294       24                        430                        523
# 1295       19
# 1296       20
# 1297       18
# 1298       22                        450                        560
# 1299       23                        420                        560
# 1300       22                        410                        520
# 1301       23
#
#             ...         Estimated personal spending  Pct of faculty with PhDs  \
# 0           ...                                1500                        76
# 1           ...                                2304                        67
# 2           ...                                1162                        39
# 3           ...                                1260                        48
# 4           ...                                 850                        53
# 5           ...                                                            52
# 6           ...                                 600                        72
# 7           ...                                                            48
# 8           ...                                1908                        85
# 9           ...                                 900                        74
# 10          ...                                                            62
# 11          ...                                1100                        63
# 12          ...                                1500                        66
# 13          ...                                                            70
# 14          ...                                2100                        58
# 15          ...                                1000                        35
# 16          ...                                1200                        59
# 17          ...                                2500                        52
# 18          ...                                1650                        74
# 19          ...                                 900                        80
# 20          ...                                1000                        47
# 21          ...                                1400                        56
# 22          ...                                                            50
# 23          ...                                1425                        70
# 24          ...                                1654                        80
# 25          ...                                2200                        96
# 26          ...                                2100                        83
# 27          ...                                1470                        80
# 28          ...                                2500                        74
# 29          ...                                2800                        54
# ...         ...                                 ...                       ...
# 1272        ...                                2245                        51
# 1273        ...                                1750                        78
# 1274        ...                                1260                        80
# 1275        ...                                1700
# 1276        ...                                1500                        66
# 1277        ...                                1357                        69
# 1278        ...                                1230
# 1279        ...                                1960                        75
# 1280        ...                                1200                        90
# 1281        ...                                                            87
# 1282        ...                                1890                        73
# 1283        ...                                1400                        48
# 1284        ...                                1800                        40
# 1285        ...                                1500                        80
# 1286        ...                                2026                        24
# 1287        ...                                1874                        55
# 1288        ...                                                            64
# 1289        ...                                                            37
# 1290        ...                                2000                        25
# 1291        ...                                1560                        77
# 1292        ...                                 750                        26
# 1293        ...                                 620                        46
# 1294        ...                                1665                        57
# 1295        ...                                1210                        33
# 1296        ...
# 1297        ...                                 750                        38
# 1298        ...                                                            83
# 1299        ...                                1100                        58
# 1300        ...                                 600                        66
# 1301        ...                                1500                        91
#
#       Pct of faculty with terminal degree  Student/faculty ratio  \
# 0                                      72                   11.9
# 1                                                           10.0
# 2                                      51                    9.5
# 3                                                           13.7
# 4                                      53                   14.3
# 5                                      56                   32.8
# 6                                      72                   18.9
# 7                                      53                   18.7
# 8                                      91                   16.7
# 9                                      79                   14.0
# 10                                     68                   19.4
# 11                                     72                   11.4
# 12                                     67                   20.1
# 13                                     70                   17.9
# 14                                     58                   18.8
# 15                                                          16.7
# 16                                     63                   16.6
# 17                                     52                   14.5
# 18                                     75                   14.7
# 19                                     89                   14.4
# 20                                     47                   14.3
# 21                                     58                   15.5
# 22                                     50                   23.0
# 23                                     74                   12.2
# 24                                     91                   17.3
# 25                                     96                    6.7
# 26                                     88                   12.7
# 27                                     80                   13.3
# 28                                     76                   18.1
# 29                                     54                   42.6
# ...                                   ...                    ...
# 1272                                   65                   10.7
# 1273                                   78                   21.0
# 1274                                                        19.3
# 1275                                   78                   21.3
# 1276                                   67                   20.6
# 1277                                   73                   18.1
# 1278                                                        19.2
# 1279                                   81                   15.2
# 1280                                   95                   23.1
# 1281                                   93                   18.4
# 1282                                   78                   19.2
# 1283                                   48                    8.5
# 1284                                   41                   11.5
# 1285                                                        13.0
# 1286                                   25                   16.3
# 1287                                   62                   19.2
# 1288                                   70                   12.8
# 1289                                   37                   19.6
# 1290                                   31                   17.3
# 1291                                   86                   16.6
# 1292                                   58                    2.5
# 1293                                   24                   13.0
# 1294                                   63                   16.5
# 1295                                   33                   16.3
# 1296                                   31                   15.3
# 1297                                   38                   19.2
# 1298                                   86                   13.4
# 1299                                   81                   16.4
# 1300                                   71                   14.1
# 1301                                   94                   15.1
#
#       Pct alumni who donate  Instructional expenditure per student  \
# 0                         2                                  10922
# 1                         8                                  11935
# 2                                                             9584
# 3                         6                                   8046
# 4                                                             7043
# 5                                                             3971
# 6                         8                                   5883
# 7
# 8                        18                                   6642
# 9                        34                                   8649
# 10                        5                                   4944
# 11                        9                                   7703
# 12                        6                                   4604
# 13                       27                                   5159
# 14                        4                                   4272
# 15                        2                                   4455
# 16                        4                                   5412
# 17                       12                                   7986
# 18                       17                                   9533
# 19                       23                                   8594
# 20                                                            5031
# 21                        7                                   5970
# 22                                                            4295
# 23                        7                                  10872
# 24                       29                                   6426
# 25                       16                                  16352
# 26                       12                                   8863
# 27                                                            8667
# 28                                                            4792
# 29                                                            2033
# ...                     ...                                    ...
# 1272                     31                                   8050
# 1273                     17                                   6254
# 1274                     28                                   6139
# 1275                      7                                   5946
# 1276                     25                                   7100
# 1277                     15                                   6460
# 1278
# 1279                     15                                   6490
# 1280                     16                                   5559
# 1281                     13                                   6855
# 1282                     14                                   5901
# 1283                     26                                   8960
# 1284                     15                                   8991
# 1285                     24                                  10941
# 1286                                                          2520
# 1287                     22                                   4311
# 1288                     26                                   8813
# 1289                                                          3191
# 1290                                                          3689
# 1291                     10                                   6203
# 1292                     10                                   7683
# 1293                      9                                   8946
# 1294                                                          3485
# 1295                     10                                   4249
# 1296                                                          4325
# 1297                      4                                   3839
# 1298                                                          8318
# 1299                     42                                   8080
# 1300                     27                                   7494
# 1301                     13                                   8745
#
#       Graduation rate Private or Public InterQ_Math_SAT InterQ_Verbal_SAT
# 0                  15           Private              90               120
# 1                                Public
# 2                  39            Public
# 3                                Public
# 4                  40            Public
# 5                  55           Private
# 6                  51            Public
# 7                  15            Public
# 8                  69            Public             118               106
# 9                  72           Private             210               190
# 10                 76            Public
# 11                 44           Private              90               130
# 12                 33            Public
# 13                 43           Private
# 14                 36            Public
# 15                 15           Private
# 16                 52           Private
# 17                              Private
# 18                 61           Private             100               100
# 19                 70           Private              70                90
# 20                 47           Private
# 21                 46           Private
# 22                 48            Public             130               170
# 23                 65           Private
# 24                 50            Public
# 25                 33            Public
# 26                 38            Public             140               140
# 27                 43            Public
# 28                 42            Public
# 29                               Public
# ...               ...               ...             ...               ...
# 1272               73           Private
# 1273               65            Public
# 1274               61            Public             125               120
# 1275               54            Public
# 1276               59            Public
# 1277               46            Public
# 1278               67            Public
# 1279               36            Public
# 1280               67            Public
# 1281               28            Public
# 1282               56            Public
# 1283               50           Private
# 1284               52           Private             110                90
# 1285               59           Private
# 1286               42            Public
# 1287               49           Private
# 1288               94           Private             140               110
# 1289               50            Public
# 1290               65            Public
# 1291               50           Private
# 1292               57           Private             120               100
# 1293               98           Private             210               190
# 1294               46           Private              93                80
# 1295               60            Public
# 1296               56            Public
# 1297                             Public
# 1298               57            Public             110               110
# 1299               67           Private             140               130
# 1300               72           Private             110               110
# 1301               45            Public
#
# [1302 rows x 38 columns]

# %%
# Save the data frame to a .csv file
# Specifying index=False prevents us from writing a column of row numbers

file_usNews.to_csv("new_usnews.csv", index=False)
